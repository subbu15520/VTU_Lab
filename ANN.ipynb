# %%
import numpy as np

X = np.array(([2,9], [1,5], [3,9]))
Y = np.array(([92], [86], [89]))

X = X/np.amax(X, axis=0)
Y = Y/100

# %%
class NeuralNetwork(object):
    def __init__(self):
        self.input_layers_size: 2
        self.hidden_layers_size: 3
        self.output_layers_size: 1
            
        self.w1 = np.random.rand(2,3)
        self.w2 = np.random.rand(3,1)
        
    def forward(self,X):
        self.z = np.dot(X,self.w1)
        self.z2 = 1/(1+np.exp(-self.z))
        self.z3 = np.dot(self.z2, self.w2)
        
        output = 1/(1+np.exp(-self.z3))
        return output
    
    def backward(self,X,Y,predicted_output):
        self.output_error = Y - predicted_output
        self.output_delta = self.output_error * (predicted_output * (1 - predicted_output))
        
        self.z2_error = self.output_delta.dot(self.w2.T)
        self.z2_delta = self.z2_error * (self.z2 * (1 - self.z2))
        
        self.w1 += learning_rate * X.T.dot(self.z2_delta)
        self.w2 += learning_rate * self.z2.T.dot(self.output_delta)

# %%
NN = NeuralNetwork()

# %%
learning_rate = 0.1

for i in range(30):
    print("Epoch: ",i)
    print("Learning Rate:\n", learning_rate)
    print("Input\n", str(X) )
    print("Actual Output:\n", str(Y))
    predicted_output = NN.forward(X)
    print("Predicted output:\n", predicted_output)
    print("Loss:\n", str(np.mean(np.square(Y - predicted_output))))
    print("\n\n")
    
    NN.backward(X,Y,predicted_output)
# Out:
# Epoch:  0
# Learning Rate:
#  0.1
# Input
#  [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         1.        ]]
# Actual Output:
#  [[0.92]
#  [0.86]
#  [0.89]]
# Predicted output:
#  [[0.65996493]
#  [0.64369459]
#  [0.66826417]]
# Loss:
#  0.05452434830198974
#
#
#
# Epoch:  1
# Learning Rate:
#  0.1
# Input
#  [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         1.        ]]
# Actual Output:
#  [[0.92]
#  [0.86]
#  [0.89]]
# Predicted output:
#  [[0.66471917]
#  [0.64795857]
#  [0.67324826]]
# Loss:
#  0.05237039604850922
#
#
#
# Epoch:  2
# Learning Rate:
#  0.1
# Input
#  [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         1.        ]]
# Actual Output:
#  [[0.92]
#  [0.86]
#  [0.89]]
# Predicted output:
#  [[0.669323  ]
#  [0.65209188]
#  [0.67807083]]
# Loss:
#  0.05032624003452362
#
#
#
# Epoch:  3
# Learning Rate:
#  0.1
# Input
#  [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         1.        ]]
# Actual Output:
#  [[0.92]
#  [0.86]
#  [0.89]]
# Predicted output:
#  [[0.67378209]
#  [0.65609936]
#  [0.68273805]]
# Loss:
#  0.04838541500377903
#
#
#
# Epoch:  4
# Learning Rate:
#  0.1
# Input
#  [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         1.        ]]
# Actual Output:
#  [[0.92]
#  [0.86]
#  [0.89]]
# Predicted output:
#  [[0.67810194]
#  [0.65998572]
#  [0.6872559 ]]
# Loss:
#  0.04654185041089678
#
#
#
# Epoch:  5
# Learning Rate:
#  0.1
# Input
#  [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         1.        ]]
# Actual Output:
#  [[0.92]
#  [0.86]
#  [0.89]]
# Predicted output:
#  [[0.68228785]
#  [0.66375552]
#  [0.69163018]]
# Loss:
#  0.04478984986115412
#
#
#
# Epoch:  6
# Learning Rate:
#  0.1
# Input
#  [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         1.        ]]
# Actual Output:
#  [[0.92]
#  [0.86]
#  [0.89]]
# Predicted output:
#  [[0.68634496]
#  [0.66741313]
#  [0.69586646]]
# Loss:
#  0.04312407069010646
#
#
#
# Epoch:  7
# Learning Rate:
#  0.1
# Input
#  [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         1.        ]]
# Actual Output:
#  [[0.92]
#  [0.86]
#  [0.89]]
# Predicted output:
#  [[0.6902782 ]
#  [0.6709628 ]
#  [0.69997014]]
# Loss:
#  0.04153950390771942
#
#
#
# Epoch:  8
# Learning Rate:
#  0.1
# Input
#  [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         1.        ]]
# Actual Output:
#  [[0.92]
#  [0.86]
#  [0.89]]
# Predicted output:
#  [[0.69409236]
#  [0.67440862]
#  [0.70394641]]
# Loss:
#  0.040031454677273
#
#
#
# Epoch:  9
# Learning Rate:
#  0.1
# Input
#  [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         1.        ]]
# Actual Output:
#  [[0.92]
#  [0.86]
#  [0.89]]
# Predicted output:
#  [[0.697792  ]
#  [0.6777545 ]
#  [0.70780024]]
# Loss:
#  0.03859552345436166
#
#
#
# Epoch:  10
# Learning Rate:
#  0.1
# Input
#  [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         1.        ]]
# Actual Output:
#  [[0.92]
#  [0.86]
#  [0.89]]
# Predicted output:
#  [[0.70138155]
#  [0.68100421]
#  [0.71153644]]
# Loss:
#  0.03722758787451818
#
#
#
# Epoch:  11
# Learning Rate:
#  0.1
# Input
#  [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         1.        ]]
# Actual Output:
#  [[0.92]
#  [0.86]
#  [0.89]]
# Predicted output:
#  [[0.70486522]
#  [0.68416139]
#  [0.7151596 ]]
# Loss:
#  0.03592378544813574
#
#
#
# Epoch:  12
# Learning Rate:
#  0.1
# Input
#  [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         1.        ]]
# Actual Output:
#  [[0.92]
#  [0.86]
#  [0.89]]
# Predicted output:
#  [[0.70824708]
#  [0.68722952]
#  [0.71867413]]
# Loss:
#  0.03468049709737737
#
#
#
# Epoch:  13
# Learning Rate:
#  0.1
# Input
#  [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         1.        ]]
# Actual Output:
#  [[0.92]
#  [0.86]
#  [0.89]]
# Predicted output:
#  [[0.71153102]
#  [0.69021193]
#  [0.72208427]]
# Loss:
#  0.033494331550708946
#
#
#
# Epoch:  14
# Learning Rate:
#  0.1
# Input
#  [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         1.        ]]
# Actual Output:
#  [[0.92]
#  [0.86]
#  [0.89]]
# Predicted output:
#  [[0.71472079]
#  [0.69311182]
#  [0.72539407]]
# Loss:
#  0.03236211059574385
#
#
#
# Epoch:  15
# Learning Rate:
#  0.1
# Input
#  [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         1.        ]]
# Actual Output:
#  [[0.92]
#  [0.86]
#  [0.89]]
# Predicted output:
#  [[0.71781994]
#  [0.69593226]
#  [0.72860741]]
# Loss:
#  0.031280855179548074
#
#
#
# Epoch:  16
# Learning Rate:
#  0.1
# Input
#  [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         1.        ]]
# Actual Output:
#  [[0.92]
#  [0.86]
#  [0.89]]
# Predicted output:
#  [[0.72083192]
#  [0.6986762 ]
#  [0.731728  ]]
# Loss:
#  0.030247772336810766
#
#
#
# Epoch:  17
# Learning Rate:
#  0.1
# Input
#  [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         1.        ]]
# Actual Output:
#  [[0.92]
#  [0.86]
#  [0.89]]
# Predicted output:
#  [[0.72376   ]
#  [0.70134646]
#  [0.7347594 ]]
# Loss:
#  0.02926024291983025
#
#
#
# Epoch:  18
# Learning Rate:
#  0.1
# Input
#  [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         1.        ]]
# Actual Output:
#  [[0.92]
#  [0.86]
#  [0.89]]
# Predicted output:
#  [[0.72660732]
#  [0.70394572]
#  [0.73770501]]
# Loss:
#  0.028315810099666595
#
#
#
# Epoch:  19
# Learning Rate:
#  0.1
# Input
#  [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         1.        ]]
# Actual Output:
#  [[0.92]
#  [0.86]
#  [0.89]]
# Predicted output:
#  [[0.72937689]
#  [0.70647659]
#  [0.74056808]]
# Loss:
#  0.02741216860470491
#
#
#
# Epoch:  20
# Learning Rate:
#  0.1
# Input
#  [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         1.        ]]
# Actual Output:
#  [[0.92]
#  [0.86]
#  [0.89]]
# Predicted output:
#  [[0.73207159]
#  [0.70894152]
#  [0.74335173]]
# Loss:
#  0.026547154660958333
#
#
#
# Epoch:  21
# Learning Rate:
#  0.1
# Input
#  [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         1.        ]]
# Actual Output:
#  [[0.92]
#  [0.86]
#  [0.89]]
# Predicted output:
#  [[0.73469418]
#  [0.7113429 ]
#  [0.74605894]]
# Loss:
#  0.025718736597466336
#
#
#
# Epoch:  22
# Learning Rate:
#  0.1
# Input
#  [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         1.        ]]
# Actual Output:
#  [[0.92]
#  [0.86]
#  [0.89]]
# Predicted output:
#  [[0.73724728]
#  [0.713683  ]
#  [0.74869255]]
# Loss:
#  0.02492500607990508
#
#
#
# Epoch:  23
# Learning Rate:
#  0.1
# Input
#  [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         1.        ]]
# Actual Output:
#  [[0.92]
#  [0.86]
#  [0.89]]
# Predicted output:
#  [[0.73973342]
#  [0.71596398]
#  [0.75125528]]
# Loss:
#  0.02416416993585351
#
#
#
# Epoch:  24
# Learning Rate:
#  0.1
# Input
#  [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         1.        ]]
# Actual Output:
#  [[0.92]
#  [0.86]
#  [0.89]]
# Predicted output:
#  [[0.74215502]
#  [0.71818794]
#  [0.75374975]]
# Loss:
#  0.023434542535913722
#
#
#
# Epoch:  25
# Learning Rate:
#  0.1
# Input
#  [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         1.        ]]
# Actual Output:
#  [[0.92]
#  [0.86]
#  [0.89]]
# Predicted output:
#  [[0.74451439]
#  [0.72035686]
#  [0.75617844]]
# Loss:
#  0.022734538695956496
#
#
#
# Epoch:  26
# Learning Rate:
#  0.1
# Input
#  [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         1.        ]]
# Actual Output:
#  [[0.92]
#  [0.86]
#  [0.89]]
# Predicted output:
#  [[0.74681374]
#  [0.72247265]
#  [0.75854373]]
# Loss:
#  0.022062667067057673
#
#
#
# Epoch:  27
# Learning Rate:
#  0.1
# Input
#  [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         1.        ]]
# Actual Output:
#  [[0.92]
#  [0.86]
#  [0.89]]
# Predicted output:
#  [[0.74905519]
#  [0.72453716]
#  [0.76084791]]
# Loss:
#  0.02141752398114405
#
#
#
# Epoch:  28
# Learning Rate:
#  0.1
# Input
#  [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         1.        ]]
# Actual Output:
#  [[0.92]
#  [0.86]
#  [0.89]]
# Predicted output:
#  [[0.75124077]
#  [0.72655212]
#  [0.76309315]]
# Loss:
#  0.020797787721913163
#
#
#
# Epoch:  29
# Learning Rate:
#  0.1
# Input
#  [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         1.        ]]
# Actual Output:
#  [[0.92]
#  [0.86]
#  [0.89]]
# Predicted output:
#  [[0.75337241]
#  [0.72851922]
#  [0.76528156]]
# Loss:
#  0.02020221319219091
